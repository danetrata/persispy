# %%
import persispy.samples.points as pips
import persispy.weighted_simplicial_complex as wsc

# %matplotlib inline

# %%
g=wsc.wRandomGraphGraph(15,.1,.1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-8512ed57fcdd> in <module>()
# ----> 1 g=wsc.wRandomGraphGraph(15,.1,.1)
#
# AttributeError: 'module' object has no attribute 'wRandomGraphGraph'

# %%
g.connected_components_1()
# Out:
# 10

# %%
a=pips.sphere(5000)
b=pips.sphere(5000,method='normalized')
c=pips.sphere(5000,method='rectangular')
d=pips.torus(5000)
e=pips.flat_torus(5000)
f=pips.cube(3,4000)

# %%
for x in [a,b,c,d,e,f]:
    x.plot3d_neighborhood_graph(.1)

# %%
d.plot3d_neighborhood_graph(.2)
# Out:
# True

# %%
y=phc(eqn="x^3+y^3+z^3-1",num_points=5000,return_complex=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6737c4d7174a> in <module>()
# ----> 1 y=phc(eqn="x^3+y^3+z^3-1",num_points=5000,return_complex=True)
#
# NameError: name 'phc' is not defined

# %%
g=d.neighborhood_graph(.2)
g.connected_components_1()
# Out:
# 17

# %%
y.plot3d_neighborhood_graph(.1)
